# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.dpi'] = 100
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set(style="whitegrid")
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import mage_ai
import lightgbm as lgb

# %%
train_df = pd.read_csv("train_weather.csv")
train_df
# Out:
#              Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0            Brisbane     13.7     23.6       0.0          5.0       9.6
# 1              Sydney     15.4     21.2      61.2          5.8       2.7
# 2            Richmond     16.8     30.9       1.0          NaN       NaN
# 3       NorfolkIsland     13.9     17.1       0.2          3.8       8.9
# 4             Mildura     16.0     36.1       0.0          6.8      12.9
# ...               ...      ...      ...       ...          ...       ...
# 121868      GoldCoast     17.6     25.1       0.0          NaN       NaN
# 121869       Adelaide     15.1     25.2       0.0         10.0      11.3
# 121870    MountGinini     10.5     18.4       1.2          NaN       NaN
# 121871       Adelaide     13.6     19.8       2.6          NaN       7.5
# 121872        Walpole      6.9     15.9       0.2          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0              SSE           24.0        SSW        ESE  ...         65.0
# 1                S           43.0        WSW        SSW  ...         91.0
# 2               NE           35.0        NNW         NE  ...         80.0
# 3               SE           37.0         SE        SSE  ...         56.0
# 4              ENE           33.0        ENE          E  ...         58.0
# ...            ...            ...        ...        ...  ...          ...
# 121868         SSE           56.0         SE          E  ...         58.0
# 121869          SW           48.0          S        WSW  ...         55.0
# 121870         SSE           50.0          E          E  ...         97.0
# 121871         WSW           54.0        WSW        WSW  ...         76.0
# 121872           N           20.0          N          S  ...         70.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              53.0       1028.4       1026.7       1.0       1.0     18.3
# 1              65.0       1018.8       1016.5       8.0       7.0     15.6
# 2              38.0       1020.4       1013.2       1.0       NaN     19.6
# 3              63.0       1027.7       1026.1       3.0       1.0     15.3
# 4              32.0       1018.5       1016.0       0.0       3.0     26.0
# ...             ...          ...          ...       ...       ...      ...
# 121868         58.0       1012.8       1010.2       NaN       NaN     23.5
# 121869         41.0       1018.8       1018.3       NaN       NaN     19.0
# 121870         93.0          NaN          NaN       NaN       NaN     12.5
# 121871         46.0       1008.5       1007.4       NaN       NaN     14.4
# 121872         65.0       1029.7       1026.7       NaN       NaN     10.7
#
#         Temp3pm  RainToday  RainTomorrow
# 0          22.3          0             0
# 1          20.7          1             1
# 2          30.0          0             0
# 3          15.8          0             0
# 4          34.9          0             0
# ...         ...        ...           ...
# 121868     24.2          0             0
# 121869     24.6          0             0
# 121870     15.9          1             1
# 121871     18.9          1             1
# 121872     14.3          0             0
#
# [121873 rows x 22 columns]

# %%
# Cleaning the data
mage_ai.connect_data(train_df, name='train_weather')
mage_ai.launch()

# %%
# Cleaning the data
mage_ai.clean(train_df, pipeline_uuid=1)
train_df
# Out:
#              Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0            brisbane     13.7     23.6       0.0          5.0       9.6
# 1              sydney     15.4     21.2      61.2          5.8       2.7
# 2            richmond     16.8     30.9       1.0          NaN       NaN
# 3       norfolkisland     13.9     17.1       0.2          3.8       8.9
# 4             mildura     16.0     36.1       0.0          6.8      12.9
# ...               ...      ...      ...       ...          ...       ...
# 121868      goldcoast     17.6     25.1       0.0          NaN       NaN
# 121869       adelaide     15.1     25.2       0.0         10.0      11.3
# 121870    mountginini     10.5     18.4       1.2          NaN       NaN
# 121871       adelaide     13.6     19.8       2.6          NaN       7.5
# 121872        walpole      6.9     15.9       0.2          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  \
# 0              SSE           24.0        SSW        ESE  ...         65.0
# 1                S           43.0        WSW        SSW  ...         91.0
# 2               NE           35.0        NNW         NE  ...         80.0
# 3               SE           37.0         SE        SSE  ...         56.0
# 4              ENE           33.0        ENE          E  ...         58.0
# ...            ...            ...        ...        ...  ...          ...
# 121868         SSE           56.0         SE          E  ...         58.0
# 121869          SW           48.0          S        WSW  ...         55.0
# 121870         SSE           50.0          E          E  ...         97.0
# 121871         WSW           54.0        WSW        WSW  ...         76.0
# 121872           N           20.0          N          S  ...         70.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              53.0       1028.4       1026.7       1.0       1.0     18.3
# 1              65.0       1018.8       1016.5       8.0       7.0     15.6
# 2              38.0       1020.4       1013.2       1.0       NaN     19.6
# 3              63.0       1027.7       1026.1       3.0       1.0     15.3
# 4              32.0       1018.5       1016.0       0.0       3.0     26.0
# ...             ...          ...          ...       ...       ...      ...
# 121868         58.0       1012.8       1010.2       NaN       NaN     23.5
# 121869         41.0       1018.8       1018.3       NaN       NaN     19.0
# 121870         93.0          NaN          NaN       NaN       NaN     12.5
# 121871         46.0       1008.5       1007.4       NaN       NaN     14.4
# 121872         65.0       1029.7       1026.7       NaN       NaN     10.7
#
#         Temp3pm  RainToday  RainTomorrow
# 0          22.3          0             0
# 1          20.7          1             1
# 2          30.0          0             0
# 3          15.8          0             0
# 4          34.9          0             0
# ...         ...        ...           ...
# 121868     24.2          0             0
# 121869     24.6          0             0
# 121870     15.9          1             1
# 121871     18.9          1             1
# 121872     14.3          0             0
#
# [121873 rows x 22 columns]

# %%
# Unbalanced data
train_df.RainTomorrow.value_counts()
# Out:
# 0    95015
# 1    26858
# Name: RainTomorrow, dtype: int64

# %%
# Categorical features
train_df.select_dtypes('object').columns
# Out:
# Index(['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm'], dtype='object')

# %%
# Remove missing values
train_df.dropna(inplace=True)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49101 entries, 0 to 121867
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       49101 non-null  object
#  1   MinTemp        49101 non-null  float64
#  2   MaxTemp        49101 non-null  float64
#  3   Rainfall       49101 non-null  float64
#  4   Evaporation    49101 non-null  float64
#  5   Sunshine       49101 non-null  float64
#  6   WindGustDir    49101 non-null  object
#  7   WindGustSpeed  49101 non-null  float64
#  8   WindDir9am     49101 non-null  object
#  9   WindDir3pm     49101 non-null  object
#  10  WindSpeed9am   49101 non-null  float64
#  11  WindSpeed3pm   49101 non-null  float64
#  12  Humidity9am    49101 non-null  float64
#  13  Humidity3pm    49101 non-null  float64
#  14  Pressure9am    49101 non-null  float64
#  15  Pressure3pm    49101 non-null  float64
#  16  Cloud9am       49101 non-null  float64
#  17  Cloud3pm       49101 non-null  float64
#  18  Temp9am        49101 non-null  float64
#  19  Temp3pm        49101 non-null  float64
#  20  RainToday      49101 non-null  int64
#  21  RainTomorrow   49101 non-null  int64
# dtypes: float64(16), int64(2), object(4)
# memory usage: 8.6+ MB

# %%
# Label encoding
categorical_features = ['WindGustDir', 'WindDir9am', 'WindDir3pm']
label_encoder = LabelEncoder()

train_df[categorical_features] = train_df[categorical_features].apply(label_encoder.fit_transform)

train_df
# Out:
#              Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0            brisbane     13.7     23.6       0.0          5.0       9.6
# 1              sydney     15.4     21.2      61.2          5.8       2.7
# 3       norfolkisland     13.9     17.1       0.2          3.8       8.9
# 4             mildura     16.0     36.1       0.0          6.8      12.9
# 7             woomera     18.4     37.9       0.0         13.6      13.0
# ...               ...      ...      ...       ...          ...       ...
# 121862  norfolkisland     19.6     23.8       0.6          4.0      11.4
# 121863         cairns     15.8     27.4       0.0          6.4      10.9
# 121864       watsonia     18.0     26.1       0.2          4.2       0.0
# 121866          moree     22.1     32.6       0.2          9.4       7.5
# 121867  sydneyairport     13.2     21.7      10.2          6.4      11.2
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity9am  \
# 0                10           24.0          11           2  ...         65.0
# 1                 8           43.0          15          11  ...         91.0
# 3                 9           37.0           9          10  ...         56.0
# 4                 1           33.0           1           0  ...         58.0
# 7                 9           39.0           9           4  ...         38.0
# ...             ...            ...         ...         ...  ...          ...
# 121862            9           43.0           9           9  ...         64.0
# 121863            4           30.0           9           4  ...         68.0
# 121864            2           20.0          13          15  ...         91.0
# 121866            1           61.0           0           0  ...         41.0
# 121867            8           54.0          11           8  ...         73.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              53.0       1028.4       1026.7       1.0       1.0     18.3
# 1              65.0       1018.8       1016.5       8.0       7.0     15.6
# 3              63.0       1027.7       1026.1       3.0       1.0     15.3
# 4              32.0       1018.5       1016.0       0.0       3.0     26.0
# 7              12.0       1015.1       1013.4       1.0       1.0     23.8
# ...             ...          ...          ...       ...       ...      ...
# 121862         59.0       1014.8       1013.0       2.0       2.0     22.1
# 121863         58.0       1017.2       1013.6       1.0       0.0     22.3
# 121864         71.0       1016.1       1012.4       8.0       8.0     19.8
# 121866         26.0       1009.4       1006.3       6.0       4.0     24.4
# 121867         63.0       1022.0       1021.7       7.0       1.0     17.4
#
#         Temp3pm  RainToday  RainTomorrow
# 0          22.3          0             0
# 1          20.7          1             1
# 3          15.8          0             0
# 4          34.9          0             0
# 7          35.8          0             0
# ...         ...        ...           ...
# 121862     22.9          0             0
# 121863     26.1          0             0
# 121864     25.4          0             1
# 121866     31.2          0             0
# 121867     20.0          1             0
#
# [49101 rows x 22 columns]

# %%
# Split data
X, y = train_df.drop(["Location", "RainTomorrow"], axis=1), train_df[["RainTomorrow"]].values.flatten()
X_train, X_eval, y_train, y_eval = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
# LightGBM Model
clf = lgb.LGBMClassifier()
clf.fit(X_train, y_train)

y_pred=clf.predict(X_eval.values)

# %%
# Classification report
print(classification_report(y_eval, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      9627
#            1       0.72      0.55      0.62      2649
#
#     accuracy                           0.86     12276
#    macro avg       0.80      0.75      0.77     12276
# weighted avg       0.85      0.86      0.85     12276

# %%
# Prediction test data
test_df = pd.read_csv("test_weather.csv")
test_df
# Out:
#             Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0         PearceRAAF     11.0     22.1       0.0          NaN       8.2
# 1             Albury      5.6     20.7       0.0          NaN       NaN
# 2              Cobar      9.5     18.4       0.0          1.6       NaN
# 3             Albany     18.4     22.0       0.0          3.8       0.2
# 4       MountGambier     10.4     20.7       0.4          3.8       9.0
# ...              ...      ...      ...       ...          ...       ...
# 13536  BadgerysCreek     13.1     26.7       0.2          NaN       NaN
# 13537       Richmond     16.4     30.1       0.0          5.6       NaN
# 13538          Uluru     22.9     32.9       0.0          NaN       NaN
# 13539           Nhil     12.5     34.2       0.0          NaN       NaN
# 13540       Canberra      1.1     13.1       0.0          2.4       0.2
#
#       WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  WindSpeed3pm  \
# 0             ESE           57.0          E          E  ...          22.0
# 1             ESE           44.0         SE        NNE  ...          24.0
# 2              SW           26.0        WNW        SSW  ...          15.0
# 3             NaN            NaN          E        ESE  ...          19.0
# 4             SSW           43.0        WSW         SW  ...          26.0
# ...           ...            ...        ...        ...  ...           ...
# 13536           W           52.0          N        WNW  ...          28.0
# 13537         WSW           43.0        ENE        WSW  ...          20.0
# 13538           E           52.0          E        ESE  ...          20.0
# 13539         SSE           31.0          E        ESE  ...          13.0
# 13540         NNW           30.0         SE        WNW  ...           6.0
#
#        Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0             52.0         34.0       1028.5       1024.6       3.0       NaN
# 1             65.0         42.0       1023.0       1018.1       NaN       NaN
# 2             67.0         43.0       1024.7       1021.5       7.0       7.0
# 3             80.0         79.0       1019.5       1017.0       8.0       8.0
# 4             55.0         38.0       1019.5       1022.4       5.0       4.0
# ...            ...          ...          ...          ...       ...       ...
# 13536         58.0         35.0       1005.4       1003.9       NaN       NaN
# 13537         79.0         38.0       1003.2       1000.8       NaN       NaN
# 13538         23.0         17.0       1018.4       1015.0       NaN       1.0
# 13539         37.0         13.0       1021.8       1018.7       NaN       NaN
# 13540         87.0         92.0       1018.2       1013.2       8.0       8.0
#
#        Temp9am  Temp3pm  RainToday
# 0         14.7     20.7          0
# 1         13.9     20.3          0
# 2         11.5     17.9          0
# 3         20.7     21.4          0
# 4         15.7     18.0          0
# ...        ...      ...        ...
# 13536     19.4     26.0          0
# 13537     21.6     29.7          0
# 13538     25.2     31.4          0
# 13539     21.1     31.3          0
# 13540      7.1     10.2          0
#
# [13541 rows x 21 columns]

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13541 entries, 0 to 13540
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       13541 non-null  object
#  1   MinTemp        13409 non-null  float64
#  2   MaxTemp        13418 non-null  float64
#  3   Rainfall       13256 non-null  float64
#  4   Evaporation    7933 non-null   float64
#  5   Sunshine       7330 non-null   float64
#  6   WindGustDir    12565 non-null  object
#  7   WindGustSpeed  12573 non-null  float64
#  8   WindDir9am     12547 non-null  object
#  9   WindDir3pm     13146 non-null  object
#  10  WindSpeed9am   13365 non-null  float64
#  11  WindSpeed3pm   13258 non-null  float64
#  12  Humidity9am    13304 non-null  float64
#  13  Humidity3pm    13140 non-null  float64
#  14  Pressure9am    12159 non-null  float64
#  15  Pressure3pm    12160 non-null  float64
#  16  Cloud9am       8407 non-null   float64
#  17  Cloud3pm       8150 non-null   float64
#  18  Temp9am        13383 non-null  float64
#  19  Temp3pm        13222 non-null  float64
#  20  RainToday      13541 non-null  int64
# dtypes: float64(16), int64(1), object(4)
# memory usage: 2.2+ MB

# %%
# Label encoding
categorical_features = ['WindGustDir', 'WindDir9am', 'WindDir3pm']
label_encoder = LabelEncoder()

test_df[categorical_features] = test_df[categorical_features].apply(label_encoder.fit_transform)

test_df
# Out:
#             Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0         PearceRAAF     11.0     22.1       0.0          NaN       8.2
# 1             Albury      5.6     20.7       0.0          NaN       NaN
# 2              Cobar      9.5     18.4       0.0          1.6       NaN
# 3             Albany     18.4     22.0       0.0          3.8       0.2
# 4       MountGambier     10.4     20.7       0.4          3.8       9.0
# ...              ...      ...      ...       ...          ...       ...
# 13536  BadgerysCreek     13.1     26.7       0.2          NaN       NaN
# 13537       Richmond     16.4     30.1       0.0          5.6       NaN
# 13538          Uluru     22.9     32.9       0.0          NaN       NaN
# 13539           Nhil     12.5     34.2       0.0          NaN       NaN
# 13540       Canberra      1.1     13.1       0.0          2.4       0.2
#
#        WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  WindSpeed3pm  \
# 0                2           57.0           0           0  ...          22.0
# 1                2           44.0           9           5  ...          24.0
# 2               12           26.0          14          11  ...          15.0
# 3               16            NaN           0           2  ...          19.0
# 4               11           43.0          15          12  ...          26.0
# ...            ...            ...         ...         ...  ...           ...
# 13536           13           52.0           3          14  ...          28.0
# 13537           15           43.0           1          15  ...          20.0
# 13538            0           52.0           0           2  ...          20.0
# 13539           10           31.0           0           2  ...          13.0
# 13540            6           30.0           9          14  ...           6.0
#
#        Humidity9am  Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  \
# 0             52.0         34.0       1028.5       1024.6       3.0       NaN
# 1             65.0         42.0       1023.0       1018.1       NaN       NaN
# 2             67.0         43.0       1024.7       1021.5       7.0       7.0
# 3             80.0         79.0       1019.5       1017.0       8.0       8.0
# 4             55.0         38.0       1019.5       1022.4       5.0       4.0
# ...            ...          ...          ...          ...       ...       ...
# 13536         58.0         35.0       1005.4       1003.9       NaN       NaN
# 13537         79.0         38.0       1003.2       1000.8       NaN       NaN
# 13538         23.0         17.0       1018.4       1015.0       NaN       1.0
# 13539         37.0         13.0       1021.8       1018.7       NaN       NaN
# 13540         87.0         92.0       1018.2       1013.2       8.0       8.0
#
#        Temp9am  Temp3pm  RainToday
# 0         14.7     20.7          0
# 1         13.9     20.3          0
# 2         11.5     17.9          0
# 3         20.7     21.4          0
# 4         15.7     18.0          0
# ...        ...      ...        ...
# 13536     19.4     26.0          0
# 13537     21.6     29.7          0
# 13538     25.2     31.4          0
# 13539     21.1     31.3          0
# 13540      7.1     10.2          0
#
# [13541 rows x 21 columns]

# %%
# Replace missing values with 0
test_df.fillna(0, inplace=True)
print(test_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13541 entries, 0 to 13540
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Location       13541 non-null  object
#  1   MinTemp        13541 non-null  float64
#  2   MaxTemp        13541 non-null  float64
#  3   Rainfall       13541 non-null  float64
#  4   Evaporation    13541 non-null  float64
#  5   Sunshine       13541 non-null  float64
#  6   WindGustDir    13541 non-null  int32
#  7   WindGustSpeed  13541 non-null  float64
#  8   WindDir9am     13541 non-null  int32
#  9   WindDir3pm     13541 non-null  int32
#  10  WindSpeed9am   13541 non-null  float64
#  11  WindSpeed3pm   13541 non-null  float64
#  12  Humidity9am    13541 non-null  float64
#  13  Humidity3pm    13541 non-null  float64
#  14  Pressure9am    13541 non-null  float64
#  15  Pressure3pm    13541 non-null  float64
#  16  Cloud9am       13541 non-null  float64
#  17  Cloud3pm       13541 non-null  float64
#  18  Temp9am        13541 non-null  float64
#  19  Temp3pm        13541 non-null  float64
#  20  RainToday      13541 non-null  int64
# dtypes: float64(16), int32(3), int64(1), object(1)
# memory usage: 2.0+ MB
# None

# %%
# LightGBM Model
x_test = test_df.drop(["Location"], axis=1)
y_pred=clf.predict(x_test.values)

# %%
submission_df = pd.DataFrame({"index":test_df.index, "RainTomorrow": y_pred})
submission_df.to_csv("submission.csv", index=False)
